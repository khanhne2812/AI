# %% [markdown]
# <a href="https://colab.research.google.com/github/khanhne28/BT_AI/blob/main/week7/LT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = '/content/1.01. Simple linear regression.csv'
dataframe = pd.read_csv(url)
dataframe.head(21)
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# 5   1670  2.91
# 6   1764  3.00
# 7   1764  3.00
# 8   1792  3.01
# 9   1850  3.01
# 10  1735  3.02
# 11  1775  3.07
# 12  1735  3.08
# 13  1712  3.08
# 14  1773  3.12
# 15  1872  3.17
# 16  1755  3.17
# 17  1674  3.17
# 18  1842  3.17
# 19  1786  3.19
# 20  1761  3.19

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
url = '1.01. Simple linear regression.csv'
data = pd.read_csv(url)
x1= data['SAT']
y = data['GPA']
plt.scatter(x1,y)
plt.xlabel('SAT', fontsize=20)
plt.ylabel('GPA', fontsize=20)
plt.show()
data.hist()

correlation = data.corr()
print(correlation)
# Out:
#           SAT       GPA
# SAT  1.000000  0.637184
# GPA  0.637184  1.000000

# %%
from sklearn import linear_model
regression_model = linear_model.LinearRegression()

x1_np = x1.to_numpy()
x1_np = x1_np.reshape(-1,1)
y_np = y.to_numpy()
y_np = y_np.reshape(-1,1)
regression_model.fit(x1_np,y_np)
print(regression_model.intercept_)
print(regression_model.coef_)
# Out:
# [0.2750403]
# [[0.00165569]]

# %%
url1 = 'mtcars.csv'
data1 = pd.read_csv(url1)
data1.head()
data1.shape
data1.plot()
b = data1.corr()
print(b)
x = data1.drop(data1.columns[[0,2]],axis =1)
data1.plot(kind = 'scatter',x = 'wt',y = 'mpg',figsize = (9,9),color = 'black')
print(data1)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000
#              Unnamed: 0   mpg   disp   hp     wt
# 0             Mazda RX4  21.0  160.0  110  2.620
# 1         Mazda RX4 Wag  21.0  160.0  110  2.875
# 2            Datsun 710  22.8  108.0   93  2.320
# 3        Hornet 4 Drive  21.4  258.0  110  3.215
# 4     Hornet Sportabout  18.7  360.0  175  3.440
# 5               Valiant  18.1  225.0  105  3.460
# 6            Duster 360  14.3  360.0  245  3.570
# 7             Merc 240D  24.4  146.7   62  3.190
# 8              Merc 230  22.8  140.8   95  3.150
# 9              Merc 280  19.2  167.6  123  3.440
# 10            Merc 280C  17.8  167.6  123  3.440
# 11           Merc 450SE  16.4  275.8  180  4.070
# 12           Merc 450SL  17.3  275.8  180  3.730
# 13          Merc 450SLC  15.2  275.8  180  3.780
# ...

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit (X = pd.DataFrame (data1 ['wt']), y = data1 ['mpg']) #X viết in hoa
print(model.intercept_)
print(model.coef_)
# Out:
# 37.28512616734204
# [-5.34447157]

# %%
model.score (X = pd.DataFrame (data1 ['wt']), y = data1 ['mpg'])
X = pd.DataFrame (data1 ['wt'])
y = data1 ['mpg']

y_pred = model.predict(X)
residual = data1 ['mpg'] - y_pred
residual.describe()
# Out:
# count    3.200000e+01
# mean    -8.215650e-15
# std      2.996352e+00
# min     -4.543151e+00
# 25%     -2.364709e+00
# 50%     -1.251956e-01
# 75%      1.409561e+00
# max      6.872711e+00
# Name: mpg, dtype: float64

# %%
data1.plot (kind = 'scatter', x='wt', y = 'mpg', figsize = (9,9), color = 'black')
plt.plot(data1['wt'], y_pred, color = 'blue')

# %%
#Hồi quy đa thức (> bậc 1)
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt']**2]).T #bậc 2

model.fit(X, y = data1['mpg'])
print('Interceptcủa mô hình bậc 2: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 2: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))
# Out:
# Interceptcủa mô hình bậc 2:
# 49.93081094945181
# Coeffient của mô hình bậc 2:
# [-13.38033708   1.17108689]
# Độ chính xác của mô hình:
# 0.8190613581384094

# %%
range = np.arange(1.5, 10, 0.1)
predictor = pd.DataFrame([range, range**2]).T
y_pred = model.predict (X =predictor)
data1.plot(kind ='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot (range, y_pred, color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bậc 3
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt']**2, data1['wt']**3]).T 

model.fit(X1, y = data1['mpg'])
print('Interceptcủa mô hình bậc 3: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 3: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X1, y))
range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range**2,range**3]).T
y_pred = model.predict (X =predictor)
data1.plot(kind ='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot (range, y_pred, color = 'blue')
# Out:
# Interceptcủa mô hình bậc 3:
# 48.40369622795221
# Coeffient của mô hình bậc 3:
# [-11.82597602   0.68937919   0.04593618]
# Độ chính xác của mô hình:
# 0.8191284628478992
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bậc 4
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt'] **2, data1['wt'] **3,
                  data1['wt'] **4]).T   
model.fit(X, y = data1['mpg'])
print('Intercept của mô hình bậc 4: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 4: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range **2, range **3,
                          range**4]).T
y_pred = model.predict(X = predictor)
data1.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9, 9), 
          color = 'red', xlim = (0, 7))
plt.plot(range, y_pred, color = 'blue')
# Out:
# Intercept của mô hình bậc 4:
# 14.455833054796258
# Coeffient của mô hình bậc 4:
# [ 36.61945631 -23.70175729   5.20042113  -0.38627878]
# Độ chính xác của mô hình:
# 0.8219709873435187
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bậc 5
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt'] **2, data1['wt'] **3,
                  data1['wt'] **4, data1['wt'] **5]).T  
model.fit(X, y = data1['mpg'])
print('Intercept của mô hình bậc 5: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 5: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range **2, range **3,
                          range**4,  range**5]).T
y_pred = model.predict(X = predictor)
data1.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9, 9), 
          color = 'red', xlim = (0, 7))
plt.plot(range, y_pred, color = 'blue')
# Out:
# Intercept của mô hình bậc 5:
# -87.71816314301019
# Coeffient của mô hình bậc 5:
# [ 218.88967608 -147.77842682   45.60934841   -6.70138798    0.37968337]
# Độ chính xác của mô hình:
# 0.8251088272653132
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bậc 6
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt'] **2, data1['wt'] **3,
                  data1['wt'] **4, data1['wt'] **5, data1['wt'] **6]).T   
model.fit(X, y = data1['mpg'])
print('Intercept của mô hình bậc 6: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 6: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range **2, range **3,
                          range**4,  range**5,  range**6]).T
y_pred = model.predict(X = predictor)
data1.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9, 9), 
          color = 'red', xlim = (0, 7))
plt.plot(range, y_pred, color = 'blue')
# Out:
# Intercept của mô hình bậc 6:
# -580.1180291191426
# Coeffient của mô hình bậc 6:
# [ 1.25251793e+03 -1.01544961e+03  4.19153811e+02 -9.38894251e+01
#   1.08661013e+01 -5.09042883e-01]
# Độ chính xác của mô hình:
# 0.8322482465599783
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bậc 7
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt'] **2, data1['wt'] **3,
                  data1['wt'] **4, data1['wt'] **5, data1['wt'] **6,
                  data1['wt'] **7]).T    
model.fit(X, y = data1['mpg'])
print('Intercept của mô hình bậc 7: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 7: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range **2, range **3,
                          range**4,  range**5,  range**6,
                           range**7]).T
y_pred = model.predict(X = predictor)
data1.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9, 9), 
          color = 'red', xlim = (0, 7))
plt.plot(range, y_pred, color = 'blue')
# Out:
# Intercept của mô hình bậc 7:
# -2387.286256135588
# Coeffient của mô hình bậc 7:
# [ 5.71347281e+03 -5.57680321e+03  2.92547757e+03 -8.93984147e+02
#   1.59440329e+02 -1.53893379e+01  6.21028572e-01]
# Độ chính xác của mô hình:
# 0.8380739929060077
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bậc 8
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt'] **2, data1['wt'] **3,
                  data1['wt'] **4, data1['wt'] **5, data1['wt'] **6,
                  data1['wt'] **7, data1['wt']**8]).T   
model.fit(X, y = data1['mpg'])
print('Intercept của mô hình bậc 8: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 8: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range **2, range **3,
                          range**4,  range**5,  range**6,
                           range**7,  range**8]).T
y_pred = model.predict(X = predictor)
data1.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9, 9), 
          color = 'red', xlim = (0, 7))
plt.plot(range, y_pred, color = 'blue')
# Out:
# Intercept của mô hình bậc 8:
# 1582.7973359661294
# Coeffient của mô hình bậc 8:
# [-5.64544414e+03  8.25196062e+03 -6.43425547e+03  2.96002820e+03
#  -8.29805697e+02  1.39294521e+02 -1.28609866e+01  5.01914523e-01]
# Độ chính xác của mô hình:
# 0.8402829929877587
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bậc 9
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt'] **2, data1['wt'] **3,
                  data1['wt'] **4, data1['wt'] **5, data1['wt'] **6,
                  data1['wt'] **7, data1['wt']**8, data1['wt'] **9]).T   
model.fit(X, y = data1['mpg'])
print('Intercept của mô hình bậc 9: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 9: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))
     
range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range **2, range **3,
                          range**4,  range**5,  range**6,
                           range**7,  range**8,  range**9]).T
y_pred = model.predict(X = predictor)
data1.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9, 9), 
          color = 'red', xlim = (0, 7))
plt.plot(range, y_pred, color = 'blue')
# Out:
# Intercept của mô hình bậc 9:
# 38889.610890257565
# Coeffient của mô hình bậc 9:
# [-1.25317627e+05  1.74784059e+05 -1.38423294e+05  6.86522656e+04
#  -2.21343938e+04  4.64432999e+03 -6.12230173e+02  4.60606389e+01
#  -1.50849985e+00]
# Độ chính xác của mô hình:
# 0.8646786785489688
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bậc 10
model = linear_model.LinearRegression()
X = pd.DataFrame([data1['wt'], data1['wt'] **2, data1['wt'] **3,
                  data1['wt'] **4, data1['wt'] **5, data1['wt'] **6,
                  data1['wt'] **7, data1['wt']**8, data1['wt'] **9, data1['wt'] **10]).T    # a1x + a2x^2 + a3x^3+ b, .T la nghich dao
model.fit(X, y = data1['mpg'])
print('Intercept của mô hình bậc 10: ')
print(model.intercept_)
print('Coeffient của mô hình bậc 10: ')
print(model.coef_)
print('Độ chính xác của mô hình: ')
print(model.score(X, y))

range = np.arange(1.5, 5.5, 0.1)
predictor = pd.DataFrame([range, range **2, range **3,
                          range**4,  range**5,  range**6,
                           range**7,  range**8,  range**9,  range**10]).T
y_pred = model.predict(X = predictor)
data1.plot(kind = 'scatter', x = 'wt', y = 'mpg', figsize = (9, 9), 
          color = 'red', xlim = (0, 7))
plt.plot(range, y_pred, color = 'blue')
# Out:
# Intercept của mô hình bậc 10:
# -14921.11995188375
# Coeffient của mô hình bậc 10:
# [ 6.45813558e+04 -1.20086131e+05  1.26931928e+05 -8.46598454e+04
#   3.73155199e+04 -1.10334755e+04  2.16590404e+03 -2.70730544e+02
#   1.94974162e+01 -6.15515436e-01]
# Độ chính xác của mô hình:
# 0.8702106571479111
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Bài 3
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
data = pd.read_csv('50_Startups.csv')
data.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
sns.pairplot(data)
corr=data.corr()
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
X=data.drop('Profit',axis=True)
y=data['Profit']
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State
# 0  165349.20       136897.80        471784.10    New York
# 1  162597.70       151377.59        443898.53  California
# 2  153441.51       101145.55        407934.54     Florida
# 3  144372.41       118671.85        383199.62    New York
# 4  142107.34        91391.77        366168.42     Florida

# %%
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
corr = data.corr()
sns.heatmap(corr,annot = True)
# Out:
# <AxesSubplot:>

# %%
X = data.drop(['State','Profit'],axis=True)
y = data['Profit']
X.head()
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0  165349.20       136897.80        471784.10
# 1  162597.70       151377.59        443898.53
# 2  153441.51       101145.55        407934.54
# 3  144372.41       118671.85        383199.62
# 4  142107.34        91391.77        366168.42

# %%
corr = data.corr()
sns.heatmap(corr,annot = True)
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (40, 3)
# (10, 3)
# (40,)
# (10,)

# %%
regression = linear_model.LinearRegression()
regression.fit(X_train, y_train)
y_pred = regression.predict(X_test.round(1))
calculation = pd.DataFrame(np.c_[y_test,y_pred],columns=['Original Profit','Predicted Profit'])
print(regression.score(X_train,y_train))
print(regression.score(X_test,y_test))
# Out:
# 0.9499572530324031
# 0.939395591782057
